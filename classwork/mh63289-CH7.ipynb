# %%
# Feb 24 class, part a challenge

import numpy as np
import time

# Jacobi method below-------------------------------------------------
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# Application of Jacobi method - prints solution, iterations, and time taken
start = time.perf_counter() # Google said perf_counter() works better than time() for short durations

A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)

b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = jacobi(A, b, x0, tol, max_iterations)

end = time.perf_counter()
elapsed_time = end - start

print("---------Jacobi Method-----------")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
if (iterations >= 100):
    print("Failed to converge within max iterations.")
print(f"Elapsed time: {elapsed_time * 1000:.6f} milliseconds")


# Gauss-Siedel method below-----------------------------------------------
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]

            # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations



# Application of Gauss-Siedel - prints solution, iterations, and time taken
start = time.perf_counter()

A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)

b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution2, iterations2 = gauss_seidel(A, b, x0, tol, max_iterations)

end = time.perf_counter()
elapsed_time2 = end - start

print("\n---------Gauss-Siedel Method-----------")
print(f"Solution: {solution2}")
print(f"Iterations: {iterations2}")
print(f"Elapsed time: {elapsed_time2 * 1000:.6f} milliseconds")
# Out:
# ---------Jacobi Method-----------
# Solution: [0.34253948 0.34219824 0.34215212 0.34233398 0.34277892]
# Iterations: 100
# Failed to converge within max iterations.
# Elapsed time: 5.641244 milliseconds
#
# ---------Gauss-Siedel Method-----------
# Solution: [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005]
# Iterations: 20
# Elapsed time: 1.540357 milliseconds

# %%
# Feb 24 class, part b challenge

import numpy as np
import time

# Jacobi method below-------------------------------------------------
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# Application of Jacobi method - prints solution, iterations, and time taken
start = time.perf_counter() # Google said perf_counter() works better than time() for short durations

A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1])

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = jacobi(A, b, x0, tol, max_iterations)

end = time.perf_counter()
elapsed_time = end - start

print("---------Jacobi Method-----------")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
if (iterations >= 100):
    print("Failed to converge within max iterations.")
print(f"Elapsed time: {elapsed_time * 1000:.6f} milliseconds")


# Gauss-Siedel method below-----------------------------------------------
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]

            # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations



# Application of Gauss-Siedel - prints solution, iterations, and time taken
start = time.perf_counter()

A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1])

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution2, iterations2 = gauss_seidel(A, b, x0, tol, max_iterations)

end = time.perf_counter()
elapsed_time2 = end - start

print("\n---------Gauss-Siedel Method-----------")
print(f"Solution: {solution2}")
print(f"Iterations: {iterations2}")
print(f"Elapsed time: {elapsed_time2 * 1000:.6f} milliseconds")
# Out:
# ---------Jacobi Method-----------
# Solution: [1 0]
# Iterations: 1
# Elapsed time: 0.908744 milliseconds
#
# ---------Gauss-Siedel Method-----------
# Solution: [1 0]
# Iterations: 1
# Elapsed time: 0.816883 milliseconds

# %%
# Feb 24 class, part c challenge

import numpy as np
import time

# Jacobi method below-------------------------------------------------
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# Application of Jacobi method - prints solution, iterations, and time taken
start = time.perf_counter() # Google said perf_counter() works better than time() for short durations

A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1.0001])

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = jacobi(A, b, x0, tol, max_iterations)

end = time.perf_counter()
elapsed_time = end - start

print("---------Jacobi Method-----------")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
if (iterations >= 100):
    print("Failed to converge within max iterations.")
print(f"Elapsed time: {elapsed_time * 1000:.6f} milliseconds")


# Gauss-Siedel method below-----------------------------------------------
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]

            # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations



# Application of Gauss-Siedel - prints solution, iterations, and time taken
start = time.perf_counter()

A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1.0001])

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution2, iterations2 = gauss_seidel(A, b, x0, tol, max_iterations)

end = time.perf_counter()
elapsed_time2 = end - start

print("\n---------Gauss-Siedel Method-----------")
print(f"Solution: {solution2}")
print(f"Iterations: {iterations2}")
print(f"Elapsed time: {elapsed_time2 * 1000:.6f} milliseconds")

# %%
# Looking at determinants

A = np.array([[2,1],[1,1]])
B = np.array([[2,4],[1,2]])
print (np.linalg.det(A))
print (np.linalg.det(B))

Ainv = np.linalg.inv(A)
# np.linalg.inv(B)
print(Ainv)

print(f"A:{A}")
kappa = np.linalg.cond(A, 2)
print(kappa)
# Out:
# 1.0
# 0.0
# [[ 1. -1.]
#  [-1.  2.]]
# A:[[2 1]
#  [1 1]]
# 6.854101966249688

# %%
# consequences of ill-conditioning 

A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1.0001])
print (np.linalg.det(A))
# print (np.linalg.det(b))

Ainv = np.linalg.inv(A)
# np.linalg.inv(B)
print(Ainv)

print(f"A:{A}")
kappa = np.linalg.cond(A, 2)
print(kappa)
# Out:
# 9.99999999999889e-05
# [[ 10001. -10000.]
#  [-10000.  10000.]]
# A:[[1.     1.    ]
#  [1.     1.0001]]
# 40002.00007491187

# %%
'''

def diagonal_dom(A) -> bool:
    """
    Checks if a matrix is diagonally dominant 
    (for each row, the absolute value of the diagonal element is >= 
    the sum of the absolute values of the other elements in that row)
    
    Args:
        A: matrix
        
    Returns: 
        True or False depending if the matrix is Diagonally Dominant 
    """
    for row in range(A[0]):
        sum_of_others = 0
        for element in range(A[0]):
            sum_of_elements = A[row][element]
        sum_of_others =- A[row][row] #create a sum of others by adding all & subtracting diagonal element
        
        if (abs((A[row][row])) <= abs(sum_of_elements)):
            return false #exits if one row fails the test
        
    return true 
        

A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)

diagonal_dom(A)

'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-491d68f7de69> in <module>
#      30  [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
#      31
# ---> 32 diagonal_dom(A)
#
# <ipython-input-18-491d68f7de69> in diagonal_dom(A)
#      11         True or False depending if the matrix is Diagonally Dominant
#      12     """
# ---> 13     for row in range(A[0]):
#      14         sum_of_others = 0
#      15         for element in range(A[0]):
#
# TypeError: only integer scalar arrays can be converted to a scalar index
